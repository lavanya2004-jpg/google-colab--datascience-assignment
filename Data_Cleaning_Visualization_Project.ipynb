# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanya2004-jpg/google-colab--datascience-assignment/blob/main/Data_Cleaning_Visualization_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/student_data.csv")

df
# Out:
#     Student_ID     Name   Age  Marks  Attendance
# 0            1    Alice  20.0     85        90.0
# 1            2      Bob  21.0     78        85.0
# 2            3  Charlie   NaN     92        95.0
# 3            4    David  22.0     88        92.0
# 4            5      Eva  20.0     76        80.0
# 5            6    Frank  23.0     95        98.0
# 6            7    Grace  21.0     89         NaN
# 7            8    Henry  22.0     73        78.0
# 8            9      Ivy  20.0     81        88.0
# 9           10     Jack  24.0    150        96.0
# 10          11     Kate  21.0     84        87.0
# 11          12     Liam  22.0     79        82.0
# 12          13      Mia   NaN     91        93.0
# 13          14     Noah  23.0     77        84.0
# 14          14     Noah  23.0     77        84.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  15 non-null     int64
#  1   Name        15 non-null     object
#  2   Age         13 non-null     float64
#  3   Marks       15 non-null     int64
#  4   Attendance  14 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 732.0+ bytes

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Age           2
# Marks         0
# Attendance    1
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Attendance'] = df['Attendance'].fillna(df['Attendance'].mean())

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Age           0
# Marks         0
# Attendance    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.boxplot(x=df['Marks'])

plt.title("Marks Boxplot")
plt.show()

# %%
df = df[df['Marks'] < 120]

# %%
df
# Out:
#     Student_ID     Name        Age  Marks  Attendance
# 0            1    Alice  20.000000     85        90.0
# 1            2      Bob  21.000000     78        85.0
# 2            3  Charlie  21.692308     92        95.0
# 3            4    David  22.000000     88        92.0
# 4            5      Eva  20.000000     76        80.0
# 5            6    Frank  23.000000     95        98.0
# 6            7    Grace  21.000000     89        88.0
# 7            8    Henry  22.000000     73        78.0
# 8            9      Ivy  20.000000     81        88.0
# 10          11     Kate  21.000000     84        87.0
# 11          12     Liam  22.000000     79        82.0
# 12          13      Mia  21.692308     91        93.0
# 13          14     Noah  23.000000     77        84.0

# %%
plt.hist(df['Marks'], bins=5)

plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Students")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.bar(df['Name'], df['Attendance'])

plt.title("Attendance of Students")
plt.xlabel("Student Name")
plt.ylabel("Attendance")

plt.xticks(rotation=45)

plt.show()

# %%
sns.heatmap(
    df[['Age','Marks','Attendance']].corr(),
    annot=True
)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# Data Cleaning & Visualization Project
#
# 1. Loaded student dataset using Pandas.
# 2. Found missing values in Age and Attendance.
# 3. Filled missing values using mean.
# 4. Found and removed duplicate records.
# 5. Detected outlier in Marks using boxplot.
# 6. Removed the outlier.
# 7. Created Histogram, Bar Chart, and Heatmap.
# 8. Observed that most students scored between 75–95 marks.
# 9. Frank had the highest attendance.
# 10. Dataset became clean and ready for analysis.
