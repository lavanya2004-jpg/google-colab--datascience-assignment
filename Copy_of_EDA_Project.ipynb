# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanya2004-jpg/google-colab--datascience-assignment/blob/main/Copy_of_EDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("student_eda.csv")

df
# Out:
#    Student_ID  Age  Hours_Studied  Attendance  Marks
# 0           1   20              2          60     45
# 1           2   21              3          65     50
# 2           3   22              4          70     55
# 3           4   20              5          75     60
# 4           5   21              6          80     68
# 5           6   22              7          85     75
# 6           7   20              8          88     82
# 7           8   21              9          90     88
# 8           9   22             10          95     92
# 9          10   20             11          98     96

# %%
df.shape
# Out:
# (10, 5)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Hours_Studied', 'Attendance', 'Marks'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student_ID     10 non-null     int64
#  1   Age            10 non-null     int64
#  2   Hours_Studied  10 non-null     int64
#  3   Attendance     10 non-null     int64
#  4   Marks          10 non-null     int64
# dtypes: int64(5)
# memory usage: 532.0 bytes

# %%
df.describe()
# Out:
#        Student_ID        Age  Hours_Studied  Attendance      Marks
# count    10.00000  10.000000       10.00000   10.000000  10.000000
# mean      5.50000  20.900000        6.50000   80.600000  71.100000
# std       3.02765   0.875595        3.02765   12.842637  18.241893
# min       1.00000  20.000000        2.00000   60.000000  45.000000
# 25%       3.25000  20.000000        4.25000   71.250000  56.250000
# 50%       5.50000  21.000000        6.50000   82.500000  71.500000
# 75%       7.75000  21.750000        8.75000   89.500000  86.500000
# max      10.00000  22.000000       11.00000   98.000000  96.000000

# %%
df.isnull().sum()
# Out:
# Student_ID       0
# Age              0
# Hours_Studied    0
# Attendance       0
# Marks            0
# dtype: int64

# %%
plt.hist(df['Marks'])

plt.title("Marks Distribution")

plt.xlabel("Marks")

plt.ylabel("Students")

plt.show()

# %%
plt.scatter(df['Attendance'],
            df['Marks'])

plt.xlabel("Attendance")

plt.ylabel("Marks")

plt.title("Attendance vs Marks")

plt.show()

# %%
plt.scatter(df['Hours_Studied'],
            df['Marks'])

plt.xlabel("Hours Studied")

plt.ylabel("Marks")

plt.title("Study Hours vs Marks")

plt.show()

# %%
corr = df.corr(numeric_only=True)

corr
# Out:
#                Student_ID       Age  Hours_Studied  Attendance    Marks
# Student_ID       1.000000  0.062869       1.000000    0.994436  0.99684
# Age              0.062869  1.000000       0.062869    0.094857  0.07026
# Hours_Studied    1.000000  0.062869       1.000000    0.994436  0.99684
# Attendance       0.994436  0.094857       0.994436    1.000000  0.99238
# Marks            0.996840  0.070260       0.996840    0.992380  1.00000

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Heatmap")

plt.show()

# %%
sns.boxplot(x=df['Marks'])

plt.title("Marks Boxplot")

plt.show()

# %%
sns.pairplot(df)

plt.show()

# %% [markdown]
# Exploratory Data Analysis Report
#
# Dataset:
# Student Performance Dataset
#
# Variables:
# 1. Age
# 2. Hours Studied
# 3. Attendance
# 4. Marks
#
# Analysis Performed:
# - Statistical Summary
# - Distribution Analysis
# - Scatter Plot Analysis
# - Correlation Analysis
# - Heatmap
# - Boxplot
#
# Insights:
# 1. Students who study more tend to score higher marks.
# 2. Attendance has a positive impact on marks.
# 3. Marks increase consistently with study hours.
# 4. No significant outliers were found.
# 5. Hours Studied and Marks show strong positive correlation.
#
# Conclusion:
# Study hours and attendance are the major factors influencing student performance.
